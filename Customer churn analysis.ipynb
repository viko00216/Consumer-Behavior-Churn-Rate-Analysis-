# %%
import pandas as pd

# %%
df = pd.read_csv("E-commerce Customer Behavior - Sheet1.csv")
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
df.describe(include = 'all')
# Out:
#         Customer ID  Gender         Age      City Membership Type  \
# count    350.000000     350  350.000000       350             350
# unique          NaN       2         NaN         6               3
# top             NaN  Female         NaN  New York            Gold
# freq            NaN     175         NaN        59             117
# mean     275.500000     NaN   33.597143       NaN             NaN
# std      101.180532     NaN    4.870882       NaN             NaN
# min      101.000000     NaN   26.000000       NaN             NaN
# 25%      188.250000     NaN   30.000000       NaN             NaN
# 50%      275.500000     NaN   32.500000       NaN             NaN
# 75%      362.750000     NaN   37.000000       NaN             NaN
# max      450.000000     NaN   43.000000       NaN             NaN
#
#         Total Spend  Items Purchased  Average Rating Discount Applied  \
# count    350.000000       350.000000      350.000000              350
# ...

# %%
# means 50% of cos tomer appear to be from new york
# 55% happens to be female
# out of unique membership gold happens to be most popular 25% costomers

# %%
# CHECK DUPLICATES

# %%
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
# showing there is no duplicates

# %%
#CHECK DESCRITION

# %%
import numpy as np

# %%
df.describe(include = [np.number])
# Out:
#        Customer ID         Age  Total Spend  Items Purchased  Average Rating  \
# count   350.000000  350.000000   350.000000       350.000000      350.000000
# mean    275.500000   33.597143   845.381714        12.600000        4.019143
# std     101.180532    4.870882   362.058695         4.155984        0.580539
# min     101.000000   26.000000   410.800000         7.000000        3.000000
# 25%     188.250000   30.000000   502.000000         9.000000        3.500000
# 50%     275.500000   32.500000   775.200000        12.000000        4.100000
# 75%     362.750000   37.000000  1160.600000        15.000000        4.500000
# max     450.000000   43.000000  1520.100000        21.000000        4.900000
#
#        Days Since Last Purchase
# count                350.000000
# mean                  26.588571
# std                   13.440813
# min                    9.000000
# 25%                   15.000000
# 50%                   23.000000
# 75%                   38.000000
# ...

# %%
df.describe(include = "object")
# Out:
#         Gender      City Membership Type Satisfaction Level
# count      350       350             350                348
# unique       2         6               3                  3
# top     Female  New York            Gold          Satisfied
# freq       175        59             117                125

# %%
#CHECK MISSTING VALUES

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
df["Satisfaction Level"] = df["Satisfaction Level"].apply(lambda x: str(x))

# %%
df["Satisfaction Level"] = df["Satisfaction Level"].str.replace('nan','')

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
#general fill with blank
df = df.fillna('')
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
#info  on time wen the weather is clear(removing RAIN)
for x in df.index:
    if df.loc[x, "Satisfaction Level"] == "":
        df.drop(x, inplace=True)
    

df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
#info  on time wen the weather is clear(removing RAIN)
for x in df.index:
    if df.loc[x, "Satisfaction Level"] == "Neutral":
        df.drop(x, inplace=True)
    

df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# 6            107  Female   31       New York            Gold      1150.60
# ..           ...     ...  ...            ...             ...          ...
# 343          444  Female   41        Chicago          Bronze       475.25
# 344          445    Male   28  San Francisco            Gold      1480.10
# 345          446    Male   32          Miami          Silver       660.30
# 347          448  Female   30       New York            Gold      1190.80
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Customer ID                 0.0
# Gender                      0.0
# Age                         0.0
# City                        0.0
# Membership Type             0.0
# Total Spend                 0.0
# Items Purchased             0.0
# Average Rating              0.0
# Discount Applied            0.0
# Days Since Last Purchase    0.0
# Satisfaction Level          0.0
# dtype: float64

# %%
# conclude there is no missing values

# %%
bool_series = df.duplicated(subset = ['Satisfaction Level'])
print(bool_series)
# Out:
# 0      False
# 2      False
# 3       True
# 4       True
# 6       True
#        ...
# 343     True
# 344     True
# 345     True
# 347     True
# 349     True
# Length: 241, dtype: bool

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          0
# dtype: int64

# %%
df.describe(include = "object")
# Out:
#        Gender      City Membership Type Satisfaction Level
# count     241       241             241                241
# unique      2         5               3                  2
# top      Male  New York            Gold          Satisfied
# freq      124        59             117                125

# %%
# CHECK UNIQUENESS
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# 6            107  Female   31       New York            Gold      1150.60
# ..           ...     ...  ...            ...             ...          ...
# 343          444  Female   41        Chicago          Bronze       475.25
# 344          445    Male   28  San Francisco            Gold      1480.10
# 345          446    Male   32          Miami          Silver       660.30
# 347          448  Female   30       New York            Gold      1190.80
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df['Customer ID'].nunique() #means all trnsaction date are diff and unique
# Out:
# 241

# %%
df['Gender'].nunique() #means all trnsaction date are diff and unique
# Out:
# 2

# %%
df['Age'].nunique() #means all trnsaction date are diff and unique
# Out:
# 12

# %%
df['City'].nunique() #means all trnsaction date are diff and unique
# Out:
# 5

# %%
df['Membership Type'].nunique() #means all trnsaction date are diff and unique
# Out:
# 3

# %%
df['Total Spend'].nunique() #means all trnsaction date are diff and unique
# Out:
# 51

# %%
df['Items Purchased'].nunique() #means all trnsaction date are diff and unique
# Out:
# 13

# %%
df['Average Rating'].nunique() #means all trnsaction date are diff and unique
# Out:
# 17

# %%
df['Discount Applied'].nunique() #means all trnsaction date are diff and unique
# Out:
# 2

# %%
df['Days Since Last Purchase'].nunique() #means all trnsaction date are diff and unique
# Out:
# 52

# %%
df['Satisfaction Level'].nunique() #means all trnsaction date are diff and unique
# Out:
# 2

# %%
# CHECKING COUNTS

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# 6            107  Female   31       New York            Gold      1150.60
# ..           ...     ...  ...            ...             ...          ...
# 343          444  Female   41        Chicago          Bronze       475.25
# 344          445    Male   28  San Francisco            Gold      1480.10
# 345          446    Male   32          Miami          Silver       660.30
# 347          448  Female   30       New York            Gold      1190.80
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df['Customer ID'].value_counts()
# Out:
# Customer ID
# 101    1
# 273    1
# 320    1
# 322    1
# 324    1
#       ..
# 222    1
# 223    1
# 224    1
# 225    1
# 450    1
# Name: count, Length: 241, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      124
# Female    117
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 30    48
# 32    33
# 43    25
# 31    25
# 27    24
# 41    24
# 28    24
# 29    11
# 42     9
# 26     9
# 33     8
# 36     1
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# New York         59
# Chicago          58
# San Francisco    58
# Miami            58
# Los Angeles       8
# Name: count, dtype: int64

# %%
df['Membership Type'].value_counts()
# Out:
# Membership Type
# Gold      117
# Silver     66
# Bronze     58
# Name: count, dtype: int64

# %%
df['Total Spend'].value_counts()
# Out:
# Total Spend
# 710.40     15
# 505.75     12
# 1190.80    11
# 1490.10    11
# 1140.60    11
# 1460.50    10
# 1470.50     8
# 660.30      8
# 1160.30     7
# 1370.20     7
# 520.40      7
# 830.75      7
# 670.30      7
# 1500.10     7
# 485.25      7
# 690.60      7
# 1130.60     7
# 480.25      7
# 680.30      7
# 1180.80     7
# 495.25      6
# 700.40      6
# 1200.80     5
# 515.75      5
# 1480.10     5
# 500.75      5
# 1450.50     4
# 1160.60     4
# 475.25      4
# 510.75      2
# 1170.30     2
# 720.40      2
# 1150.60     2
# 690.30      2
# 820.75      1
# 525.75      1
# 1480.30     1
# 700.60      1
# 1440.50     1
# 1170.80     1
# 1360.20     1
# 490.25      1
# 690.40      1
# 1420.80     1
# 1520.10     1
# 530.40      1
# 670.60      1
# 1390.20     1
# 1210.60     1
# 730.40      1
# 1120.20     1
# Name: count, dtype: int64

# %%
df['Items Purchased'].value_counts()
# Out:
# Items Purchased
# 10    47
# 9     34
# 13    32
# 15    24
# 21    24
# 16    24
# 20    19
# 14    11
# 18     9
# 12     9
# 19     6
# 11     1
# 17     1
# Name: count, dtype: int64

# %%
df['Average Rating'].value_counts()
# Out:
# Average Rating
# 4.5    31
# 3.6    24
# 3.8    24
# 3.3    24
# 4.9    24
# 4.7    22
# 4.8    21
# 4.1    17
# 4.6    11
# 3.5     9
# 3.9     8
# 4.4     8
# 4.0     8
# 4.2     7
# 3.7     1
# 3.4     1
# 4.3     1
# Name: count, dtype: int64

# %%
df['Discount Applied'].value_counts()
# Out:
# Discount Applied
# True     175
# False     66
# Name: count, dtype: int64

# %%
df['Days Since Last Purchase'].value_counts()
# Out:
# Days Since Last Purchase
# 10    17
# 39    16
# 13    12
# 12    11
# 47     9
# 14     9
# 40     9
# 9      9
# 38     9
# 54     8
# 37     8
# 33     8
# 32     8
# 22     8
# 27     8
# 20     7
# 26     7
# 19     7
# 11     6
# 53     5
# 41     4
# 42     4
# 28     4
# 35     3
# 46     3
# 25     3
# 21     3
# 34     3
# 48     3
# 29     2
# 15     2
# 55     2
# 45     2
# 36     2
# 43     2
# 44     2
# 24     1
# 63     1
# 62     1
# 61     1
# 60     1
# 59     1
# 23     1
# 31     1
# 58     1
# 30     1
# 57     1
# 56     1
# 52     1
# 18     1
# 50     1
# 49     1
# Name: count, dtype: int64

# %%
df['Satisfaction Level'].value_counts()
# Out:
# Satisfaction Level
# Satisfied      125
# Unsatisfied    116
# Name: count, dtype: int64

# %%
#CONCLUDE THAT:
# 50% of costomers are from newyork 
# 70% have gold membership 
# females seems to be higher than males for costomers

# %%
#GRAPHICAL PRESENTATION

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =( 5,5))
df['Gender'].value_counts().plot.pie(autopct ='%1.1f%%' , startangle = 90)
plt.title('GENDER DISTRIBUTION')
plt.show()

# %%
plt.figure(figsize =( 5,5))
df['Satisfaction Level'].value_counts().plot.pie(autopct ='%1.1f%%' , startangle = 90)
plt.title('LEVEL OF SATISFACTION')
plt.show()

# %%
plt.figure(figsize =( 5,5))
df['City'].value_counts().plot.pie(autopct ='%1.1f%%' , startangle = 90)
plt.title('CITY DISTRIBUTION')
plt.show()

# %%
plt.figure(figsize =( 5,5))
df['Discount Applied'].value_counts().plot.pie(autopct ='%1.1f%%' , startangle = 90)
plt.title('Discount Applied Distribution')
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize =( 5,5))
df['Membership Type'].value_counts().plot.pie(autopct ='%1.1f%%' , startangle = 90)
plt.title('Membership Type Distribution')
plt.show()

# %%
plt.figure(figsize= (10,6))
sns.countplot(x='Membership Type', data=df, palette='viridis')
plt.title('Membership Type Distribution')
plt.show()

# %%
#UNIVARIATE ANALYSIS

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# 6            107  Female   31       New York            Gold      1150.60
# ..           ...     ...  ...            ...             ...          ...
# 343          444  Female   41        Chicago          Bronze       475.25
# 344          445    Male   28  San Francisco            Gold      1480.10
# 345          446    Male   32          Miami          Silver       660.30
# 347          448  Female   30       New York            Gold      1190.80
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
# 6          107  Female   31       New York            Gold      1150.60
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
# 6               15             4.5              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 2                        42        Unsatisfied
# 3                        12          Satisfied
# ...

# %%
df.reset_index(drop=True)
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            103  Female   43        Chicago          Bronze       510.75
# 2            104    Male   30  San Francisco            Gold      1480.30
# 3            105    Male   27          Miami          Silver       720.40
# 4            107  Female   31       New York            Gold      1150.60
# ..           ...     ...  ...            ...             ...          ...
# 236          444  Female   41        Chicago          Bronze       475.25
# 237          445    Male   28  San Francisco            Gold      1480.10
# 238          446    Male   32          Miami          Silver       660.30
# 239          448  Female   30       New York            Gold      1190.80
# 240          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import ttest_1samp, ttest_ind, ttest_rel
from scipy.stats import chisquare,chi2,chi2_contingency
from scipy.stats import f_oneway
from scipy.stats import levene,kruskal

# %%
#num_col = ['Total Spend','Items Purchased','Discount Applied','Satisfaction Level']

# %%
num_col = ['Total Spend']
fig, axis = plt.subplots(nrows =3, ncols=2, figsize=(11,10))
colors = ['r','g','b','yellow','orange','pink']
index = 0
for row in range(3):
    for col in range(2):
        if index < len(num_col):
            sns.histplot(df[num_col[index]], ax=axis[row, col], kde=True, color = colors[index])

index += 1

plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#,'Items Purchased','Discount Applied','Satisfaction Level'

# %%
num_col = ['Items Purchased']
fig, axis = plt.subplots(nrows =3, ncols=2, figsize=(11,10))
colors = ['r','g','b','yellow','orange','pink']
index = 0
for row in range(3):
    for col in range(2):
        if index < len(num_col):
            sns.histplot(df[num_col[index]], ax=axis[row, col], kde=True, color = colors[index])

index += 1

plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
num_col = ['Discount Applied']
fig, axis = plt.subplots(nrows =3, ncols=2, figsize=(11,10))
colors = ['r','g','b','yellow','orange','pink']
index = 0
for row in range(3):
    for col in range(2):
        if index < len(num_col):
            sns.histplot(df[num_col[index]], ax=axis[row, col], kde=True, color = colors[index])

index += 1

plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_stats\counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_stats\counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
num_col = ['Satisfaction Level']
fig, axis = plt.subplots(nrows =3, ncols=2, figsize=(11,10))
colors = ['r','g','b','yellow','orange','pink']
index = 0
for row in range(3):
    for col in range(2):
        if index < len(num_col):
            sns.histplot(df[num_col[index]], ax=axis[row, col], kde=True, color = colors[index])

index += 1

plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
num_col = ['Days Since Last Purchase']
fig, axis = plt.subplots(nrows =3, ncols=2, figsize=(11,10))
colors = ['r','g','b','yellow','orange','pink']
index = 0
for row in range(3):
    for col in range(2):
        if index < len(num_col):
            sns.histplot(df[num_col[index]], ax=axis[row, col], kde=True, color = colors[index])

index += 1

plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#INSIGHT FROM THE THE UNIVARIATE ANALYSIS
#According to the first chart represented here is that costomers that  spent < $600 are high
# the second chart explains that there costomers mostly purchase 10 items
# ther is high discount rate
# costomers that puchase items in the last 10 days is high
# the level of satisfied is slightly higher than the unstisfied costomers and this calls for more improvement of our products cause the margin is too small
# if care is not taken the level of unsatisfied costomers will surpass the level of satisfied costomers will be low which will lead to lost of customers

# %%
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
# 6          107  Female   31       New York            Gold      1150.60
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
# 6               15             4.5              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 2                        42        Unsatisfied
# 3                        12          Satisfied
# ...

# %% [markdown]
# ###### df

# %%
#INSIGHT 
#There is 48% churn rate

# %%
df_satisfied = [(df['Satisfaction Level'] == 1)]
df_stayed = [(df['Satisfaction Level'] == 0)]

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'Age', hue ='Satisfaction Level', data=df, palette = "viridis" )
plt.title('Bivarite analysis: age vs satisfaction level')
plt.xlabel('Age')
plt.ylabel('count')
plt.show()

# %%
#By percentage
df.groupby(['Age'])['Satisfaction Level'].value_counts(normalize=True)*100
# Out:
# Age  Satisfaction Level
# 26   Unsatisfied           100.000000
# 27   Unsatisfied           100.000000
# 28   Satisfied             100.000000
# 29   Satisfied              90.909091
#      Unsatisfied             9.090909
# 30   Satisfied             100.000000
# 31   Satisfied             100.000000
# 32   Unsatisfied            72.727273
#      Satisfied              27.272727
# 33   Satisfied             100.000000
# 36   Satisfied             100.000000
# 41   Unsatisfied           100.000000
# 42   Unsatisfied           100.000000
# 43   Unsatisfied           100.000000
# Name: proportion, dtype: float64

# %%
#INSIGHT
#this tells that costumers at the age of 26 27 41 42 and 43 are likely to exite
# those at the age of 30 has the least churn rate

# %%
plt.figure(figsize=(10,6))
df['Satisfaction Level'] = df['Satisfaction Level'].replace({0: 'Usatisfied', 1:'satisfied'})
print(df.groupby(['City'])['Satisfaction Level'].value_counts())
sns.countplot(x = 'City', hue ='Satisfaction Level', data=df, palette = ["red", "green"] )
plt.title('Bivarite analysis: age vs satisfaction level')
plt.xlabel('City')
plt.ylabel('count')
plt.show()
# Out:
# City           Satisfaction Level
# Chicago        Unsatisfied           58
# Los Angeles    Satisfied              8
# Miami          Unsatisfied           58
# New York       Satisfied             59
# San Francisco  Satisfied             58
# Name: count, dtype: int64

# %%
#By percentage
df.groupby(['City'])['Satisfaction Level'].value_counts(normalize=True)*100
# Out:
# City           Satisfaction Level
# Chicago        Unsatisfied           100.0
# Los Angeles    Satisfied             100.0
# Miami          Unsatisfied           100.0
# New York       Satisfied             100.0
# San Francisco  Satisfied             100.0
# Name: proportion, dtype: float64

# %%
#INSIGHT
#there is higher chances that customers in chicago and Miami will exit
# and customers in  new york and san fancisco  will stay and they have the least churn rate
# there proportionality more people to exite in los angeles

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'Gender', hue ='Satisfaction Level', data=df, palette = "viridis" )
plt.title('Bivarite analysis: Gender vs satisfaction level')
plt.xlabel('Gender')
plt.ylabel('count')
plt.show()

# %%
#By percentage
df.groupby(['Gender'])['Satisfaction Level'].value_counts(normalize=True)*100
# Out:
# Gender  Satisfaction Level
# Female  Unsatisfied           50.427350
#         Satisfied             49.572650
# Male    Satisfied             54.032258
#         Unsatisfied           45.967742
# Name: proportion, dtype: float64

# %%
#insight
# females are more unsatisfied than males
# and there is larger number of males that are satisfied further analysis is to be carried out

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = 'Satisfaction Level',y = 'Age', data=df, palette = ["red","green"] )
plt.title('Bivarite analysis: age vs satisfaction level')
plt.xlabel('age')
plt.ylabel('count')
plt.show()

# %%
#insight 
#age impacted in the satisfaction level

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# 6            107  Female   31       New York            Gold      1150.60
# ..           ...     ...  ...            ...             ...          ...
# 343          444  Female   41        Chicago          Bronze       475.25
# 344          445    Male   28  San Francisco            Gold      1480.10
# 345          446    Male   32          Miami          Silver       660.30
# 347          448  Female   30       New York            Gold      1190.80
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
# 6          107  Female   31       New York            Gold      1150.60
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
# 6               15             4.5              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 2                        42        Unsatisfied
# 3                        12          Satisfied
# ...

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = 'Satisfaction Level',y = 'Total Spend', data=df, palette = ["red","green"] )
plt.title('Bivarite analysis: Total Spend vs satisfaction level')
plt.xlabel('Total Spend')
plt.ylabel('count')
plt.show()

# %%
# it also impacted in satisfaction level

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = 'Satisfaction Level',y = 'Items Purchased', data=df, palette = ["red","green"] )
plt.title('Bivarite analysis: Items Purchased vs satisfaction level')
plt.xlabel('Items Purchased')
plt.ylabel('count')
plt.show()

# %%
# it also impacted

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = 'Satisfaction Level',y = 'Days Since Last Purchase', data=df, palette = ["red","green"] )
plt.title('Bivarite analysis: Days Since Last Purchase vs satisfaction level')
plt.xlabel('Days Since Last Purchased')
plt.ylabel('count')
plt.show()

# %%
#it also impacted

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20, kde=True,color='skyblue')
plt.title('Bivarite analysis: age vs satisfaction level')
plt.xlabel('age')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.groupby(['Items Purchased'])['Satisfaction Level'].value_counts(normalize=True)*100
# Out:
# Items Purchased  Satisfaction Level
# 9                Unsatisfied           100.000000
# 10               Unsatisfied           100.000000
# 11               Unsatisfied           100.000000
# 12               Unsatisfied           100.000000
# 13               Unsatisfied            75.000000
#                  Satisfied              25.000000
# 14               Satisfied              90.909091
#                  Unsatisfied             9.090909
# 15               Satisfied             100.000000
# 16               Satisfied             100.000000
# 17               Satisfied             100.000000
# 18               Satisfied             100.000000
# 19               Satisfied             100.000000
# 20               Satisfied             100.000000
# 21               Satisfied             100.000000
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(30,35))
yn = ['red','green']
sns.countplot(x='Total Spend', hue = 'Satisfaction Level', data=df, palette=yn )
plt.title('Bivarite analysis: Total Spend vs satisfaction level')
plt.xlabel('Total Spend')
plt.ylabel('count')
plt.show()

# %%
df.groupby(['Total Spend'])['Satisfaction Level'].value_counts(normalize=True)*100
# Out:
# Total Spend  Satisfaction Level
# 475.25       Unsatisfied           100.0
# 480.25       Unsatisfied           100.0
# 485.25       Unsatisfied           100.0
# 490.25       Unsatisfied           100.0
# 495.25       Unsatisfied           100.0
# 500.75       Unsatisfied           100.0
# 505.75       Unsatisfied           100.0
# 510.75       Unsatisfied           100.0
# 515.75       Unsatisfied           100.0
# 520.40       Unsatisfied           100.0
# 525.75       Unsatisfied           100.0
# 530.40       Unsatisfied           100.0
# 660.30       Unsatisfied           100.0
# 670.30       Unsatisfied           100.0
# 670.60       Unsatisfied           100.0
# 680.30       Unsatisfied           100.0
# 690.30       Unsatisfied           100.0
# 690.40       Unsatisfied           100.0
# 690.60       Unsatisfied           100.0
# 700.40       Unsatisfied           100.0
# 700.60       Unsatisfied           100.0
# 710.40       Unsatisfied           100.0
# ...

# %%
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
# 6          107  Female   31       New York            Gold      1150.60
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
# 6               15             4.5              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 2                        42        Unsatisfied
# 3                        12          Satisfied
# ...

# %%
#col_matrixs = df.corr()

# %%
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
# 6          107  Female   31       New York            Gold      1150.60
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
# 6               15             4.5              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 2                        42        Unsatisfied
# 3                        12          Satisfied
# ...

# %%
df = df.drop(columns = 'Gender')

# %%
df
# Out:
#      Customer ID  Age           City Membership Type  Total Spend  \
# 0            101   29       New York            Gold      1120.20
# 2            103   43        Chicago          Bronze       510.75
# 3            104   30  San Francisco            Gold      1480.30
# 4            105   27          Miami          Silver       720.40
# 6            107   31       New York            Gold      1150.60
# ..           ...  ...            ...             ...          ...
# 343          444   41        Chicago          Bronze       475.25
# 344          445   28  San Francisco            Gold      1480.10
# 345          446   32          Miami          Silver       660.30
# 347          448   30       New York            Gold      1190.80
# 349          450   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# 0                 14             4.6              True
# 2                  9             3.4              True
# ...

# %%
df = df.drop(columns = 'Customer ID')
df
# Out:
#      Age           City Membership Type  Total Spend  Items Purchased  \
# 0     29       New York            Gold      1120.20               14
# 2     43        Chicago          Bronze       510.75                9
# 3     30  San Francisco            Gold      1480.30               19
# 4     27          Miami          Silver       720.40               13
# 6     31       New York            Gold      1150.60               15
# ..   ...            ...             ...          ...              ...
# 343   41        Chicago          Bronze       475.25                9
# 344   28  San Francisco            Gold      1480.10               21
# 345   32          Miami          Silver       660.30               10
# 347   30       New York            Gold      1190.80               16
# 349   43        Chicago          Bronze       515.75               10
#
#      Average Rating  Discount Applied  Days Since Last Purchase  \
# ...

# %%
df["City"] = df["City"].str.replace('New York','0')
df["City"] = df["City"].str.replace('San Francisco','1')
df["City"] = df["City"].str.replace('Miami','2')
df["City"] = df["City"].str.replace('Chicago','3')
df["City"] = df["City"].str.replace('Los Angeles','4')
df


#df = df.drop(columns = 'City')
#df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0            Gold      1120.20               14             4.6
# 2     43    3          Bronze       510.75                9             3.4
# 3     30    1            Gold      1480.30               19             4.7
# 4     27    2          Silver       720.40               13             4.0
# 6     31    0            Gold      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3          Bronze       475.25                9             3.6
# 344   28    1            Gold      1480.10               21             4.9
# 345   32    2          Silver       660.30               10             3.8
# 347   30    0            Gold      1190.80               16             4.5
# 349   43    3          Bronze       515.75               10             3.3
#
# ...

# %%
#df = df.drop(columns = 'Membership Type')
#df
df["Membership Type"] = df["Membership Type"].str.replace('Gold','0')
df["Membership Type"] = df["Membership Type"].str.replace('Silver','1')
df["Membership Type"] = df["Membership Type"].str.replace('Bronze','2')
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
#df = df.drop(columns = 'Discount Applied')
#df
df['Discount Applied'] = df['Discount Applied'].replace({True:1,False:0})
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'Membership Type', hue ='Satisfaction Level', data=df, palette = "viridis" )
plt.title('Bivarite analysis: Membership Type vs satisfaction level')
plt.xlabel('Membership Type')
plt.ylabel('count')
plt.show()

# %%
df["Satisfaction Level"] = df["Satisfaction Level"].str.replace('Unsatisfied','0')
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
df["Satisfaction Level"] = df["Satisfaction Level"].str.replace('Satisfied','1')
df
#df = df.drop(columns = 'Satisfaction Level')
#df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
corr_mat = df.corr()

# %%
corr_mat['Total Spend']
# Out:
# Age                        -0.642800
# City                       -0.773175
# Membership Type            -0.928264
# Total Spend                 1.000000
# Items Purchased             0.969543
# Average Rating              0.961150
# Discount Applied           -0.710358
# Days Since Last Purchase   -0.836204
# Satisfaction Level          0.914863
# Name: Total Spend, dtype: float64

# %%
corr_mat
# Out:
#                                Age      City  Membership Type  Total Spend  \
# Age                       1.000000  0.621883         0.793997    -0.642800
# City                      0.621883  1.000000         0.893562    -0.773175
# Membership Type           0.793997  0.893562         1.000000    -0.928264
# Total Spend              -0.642800 -0.773175        -0.928264     1.000000
# Items Purchased          -0.663760 -0.666905        -0.860252     0.969543
# Average Rating           -0.757613 -0.787140        -0.951236     0.961150
# Discount Applied          0.344744  0.110060         0.477002    -0.710358
# Days Since Last Purchase  0.285513  0.490057         0.693550    -0.836204
# Satisfaction Level       -0.483607 -0.747871        -0.879056     0.914863
#
#                           Items Purchased  Average Rating  Discount Applied  \
# Age                             -0.663760       -0.757613          0.344744
# ...

# %%
corr_mat = df.corr()

# %%
corr_mat['Total Spend']
# Out:
# Age                        -0.642800
# City                       -0.773175
# Membership Type            -0.928264
# Total Spend                 1.000000
# Items Purchased             0.969543
# Average Rating              0.961150
# Discount Applied           -0.710358
# Days Since Last Purchase   -0.836204
# Satisfaction Level          0.914863
# Name: Total Spend, dtype: float64

# %%
corr_mat
# Out:
#                                Age      City  Membership Type  Total Spend  \
# Age                       1.000000  0.621883         0.793997    -0.642800
# City                      0.621883  1.000000         0.893562    -0.773175
# Membership Type           0.793997  0.893562         1.000000    -0.928264
# Total Spend              -0.642800 -0.773175        -0.928264     1.000000
# Items Purchased          -0.663760 -0.666905        -0.860252     0.969543
# Average Rating           -0.757613 -0.787140        -0.951236     0.961150
# Discount Applied          0.344744  0.110060         0.477002    -0.710358
# Days Since Last Purchase  0.285513  0.490057         0.693550    -0.836204
# Satisfaction Level       -0.483607 -0.747871        -0.879056     0.914863
#
#                           Items Purchased  Average Rating  Discount Applied  \
# Age                             -0.663760       -0.757613          0.344744
# ...

# %%
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
df.sum()
# Out:
# Age                                                                      7881
# City                        0312031204312031203120431203120312031203120431...
# Membership Type             0201020101201020102010120102010201020102010120...
# Total Spend                                                          229075.7
# Items Purchased                                                          3386
# Average Rating                                                         1009.1
# Discount Applied                                                          175
# Days Since Last Purchase                                                 7198
# Satisfaction Level          1010101011010101010101101010101010101010101101...
# dtype: object

# %%
corr_mat['Satisfaction Level']
# Out:
# Age                        -0.483607
# City                       -0.747871
# Membership Type            -0.879056
# Total Spend                 0.914863
# Items Purchased             0.837308
# Average Rating              0.896921
# Discount Applied           -0.591598
# Days Since Last Purchase   -0.857487
# Satisfaction Level          1.000000
# Name: Satisfaction Level, dtype: float64

# %%
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
df.groupby(['Membership Type'])['Satisfaction Level'].value_counts(normalize=True)*100
# Out:
# Membership Type  Satisfaction Level
# 0                1                     100.000000
# 1                0                      87.878788
#                  1                      12.121212
# 2                0                     100.000000
# Name: proportion, dtype: float64

# %%
df.groupby(['Membership Type'])['Satisfaction Level'].value_counts(normalize=True)*100
# Out:
# Membership Type  Satisfaction Level
# 0                1                     100.000000
# 1                0                      87.878788
#                  1                      12.121212
# 2                0                     100.000000
# Name: proportion, dtype: float64

# %%
#bool_to_string(True) = 'True'
#bool_to_string(False) = 'False'

# %%
#df[''] = df[''].replace({True:1,False:0})
#df

# %%
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'Discount Applied', hue ='Satisfaction Level', data=df, palette = "viridis" )
plt.title('Bivarite analysis: Discount Applied vs satisfaction level')
plt.xlabel('Discount Applied')
plt.ylabel('count')
plt.show()

# %%
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'City', hue ='Discount Applied', data=df, palette = "viridis" )
plt.title('Bivarite analysis: City vs satisfaction level')
plt.xlabel('Discount Applied')
plt.ylabel('count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[269], line 2
#       1 plt.figure(figsize=(8,5))
# ----> 2 sns.countplot(x = 'City', hue ='Discount Applied', data=df, palette = "viridis" )
#       3 plt.title('Bivarite analysis: City vs satisfaction level')
#       4 plt.xlabel('Discount Applied')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 241 entries, 0 to 349
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       241 non-null    int64
#  1   City                      241 non-null    object
#  2   Membership Type           241 non-null    object
#  3   Total Spend               241 non-null    float64
#  4   Items Purchased           241 non-null    int64
#  5   Average Rating            241 non-null    float64
#  6   Discount Applied          241 non-null    int64
#  7   Days Since Last Purchase  241 non-null    int64
#  8   Satisfaction Level        241 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 26.9+ KB

# %%
df
# Out:
#      Age City Membership Type  Total Spend  Items Purchased  Average Rating  \
# 0     29    0               0      1120.20               14             4.6
# 2     43    3               2       510.75                9             3.4
# 3     30    1               0      1480.30               19             4.7
# 4     27    2               1       720.40               13             4.0
# 6     31    0               0      1150.60               15             4.5
# ..   ...  ...             ...          ...              ...             ...
# 343   41    3               2       475.25                9             3.6
# 344   28    1               0      1480.10               21             4.9
# 345   32    2               1       660.30               10             3.8
# 347   30    0               0      1190.80               16             4.5
# 349   43    3               2       515.75               10             3.3
#
# ...
